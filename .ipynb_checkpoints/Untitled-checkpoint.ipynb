# %%
import pickle 

fr = open('MatrixD.pkl','rb')  
dat = pickle.load(fr)

# %%
dat[1995]
# Out:
# array([[2.04730000e+04, 3.07280000e+04, 0.00000000e+00, ...,
#         4.89944120e+07, 5.47486040e+07, 2.18994400e+07],
#        [1.80440000e+04, 0.00000000e+00, 1.51890000e+05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.69941100e+07, ...,
#         3.59369960e+07, 6.66660000e+07, 1.04550000e+07],
#        ...,
#        [2.08534250e+07, 5.32196060e+07, 1.37330500e+06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.54267560e+07, 1.63648317e+09, 1.28757573e+09, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.50357600e+07, 5.46218930e+07, 7.99702190e+07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
import pickle 

fr = open('cdata_res.pkl','rb')  
dat = pickle.load(fr)

# %%
dat.keys()
# Out:
# dict_keys(['ECI', 'density', 'cog', 'PCI'])

# %%
dat['ECI']
# Out:
# {'~019343c06c6a15aa47': 0.11142756821655171,
#  '~01683d57e7a51024f9': 1.212628927749765,
#  '~015fb050dd19f9bc16': 0.765076045163011,
#  '~01e5e35fe1223f04ba': -1.4259072902781535,
#  '~01102d9544289ceec8': -1.2659138931082454,
#  '~01d1ab228e72c1573c': -1.0988708341883824,
#  '~011bb34bc6b91c12e7': -1.2847054950909103,
#  '~01720ef1021c37573b': -0.5644661699507862,
#  '~01b37fdf6692c03539': 1.3389412668008336,
#  '~0137ff02d310508cc5': -0.616860538334857,
#  '~01e1563425f31c36f5': 1.1507860289688177,
#  '~017327a0017d08cbbb': 0.03434796026931167,
#  '~0107c95a116157423e': 0.7057353957166286,
#  '~012c93c5c3aad82aef': -0.09578460118231037,
#  '~018ae04f2b82b4742d': -1.2659138931082454,
#  '~01229b130c5bc29740': -1.0440984475811932,
#  '~01626550ad4346863a': 1.387693442453965,
#  '~01240cd4a45932ae7c': -1.076181981468557,
#  '~011bf21d904417d77a': 0.6260372873931979,
#  '~0171abf395217f4bb9': 1.4011324937360428,
#  '~011daf1d2e50e124c6': -1.181129982939536,
# ...
